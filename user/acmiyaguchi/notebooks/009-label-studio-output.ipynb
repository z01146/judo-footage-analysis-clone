# %%
import pandas as pd

root = "/cs-share/pradalier/tmp/judo"
df = pd.read_json(f"{root}/data/annotations/entity-detection-2024-03-19-min.json")
df
# Out:
#                                                   image     id  \
# 0     http://localhost:8080/data/frames/mat_01/0003/...  36121
# 1     http://localhost:8080/data/frames/mat_01/0003/...  36122
# 2     http://localhost:8080/data/frames/mat_01/0003/...  36123
# 3     http://localhost:8080/data/frames/mat_01/0003/...  36124
# 4     http://localhost:8080/data/frames/mat_01/0003/...  36125
# ...                                                 ...    ...
# 1291  http://localhost:8080/data/frames/mat_07/0002/...  72062
# 1292  http://localhost:8080/data/frames/mat_07/0002/...  72063
# 1293  http://localhost:8080/data/frames/mat_07/0002/...  72174
# 1294  http://localhost:8080/data/frames/mat_07/0002/...  72190
# 1295  http://localhost:8080/data/frames/mat_07/0002/...  72214
#
#                                                   label  annotator  \
# 0     [{'x': 6.474893093109131, 'y': 39.896299574110...          1
# 1     [{'x': 18.16250443458557, 'y': 27.355482313368...          4
# ...
